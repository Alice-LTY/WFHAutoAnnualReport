# %%
# main.ipynb
import os
import pandas as pd
from utils import create_output_directory, clean_data, Site_Group_InLymphoma, Hist_Behavior_Group, Site_Group, Save_separated_file, separate_class_of_carcinoma
from reports import Age_Group, Age_Gender_Report, Class_Gender_Report, clean, to_define_stage, Define_Stage_, Distribution_tabel

from Head_and_Neck_Cancer_Treatment import therapy_order_Head_Neck_

# %%
################################################################################################################################################################
def generate_and_save_reports(df, carcinoma_type):
    directory_path = f'{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}Report'
    os.makedirs(directory_path, exist_ok=True)

    age_gender_report, df_report = Age_Gender_Report(df)
    #Save file
    age_gender_report.to_excel(f'{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}Report/{year}_{carcinoma_type}_Age_Gender.xlsx', sheet_name='age_gender_report')

    class_gender_report, df_report = Class_Gender_Report(df)
    #Save file
    class_gender_report.to_excel(f'{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}Report/{year}_{carcinoma_type}_Class_Gender.xlsx', sheet_name='class_gender_report')


    df_AJCC_stage = Define_Stage_(df)
    #Save file
    df_AJCC_stage.to_excel(f'{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}Report/{year}_{carcinoma_type}_AJCC_stage.xlsx', sheet_name='AJCC_stage')


    if carcinoma_type == "白血病":
        return age_gender_report, class_gender_report

    _distribution = Type_Report(df)
    # Save file
    _distribution.to_excel(f'{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}Report/{year}_{carcinoma_type}_Type(Class1-2).xlsx', sheet_name='class_type')

    return age_gender_report, class_gender_report, _distribution, df_AJCC_stage
################################################################################################################################################################

# %%
def mount_drive():
    """Mount Google Drive in Google Colab."""
    from google.colab import drive
    drive.mount('/content/drive')
    
if __name__ == "__main__":
    while True:
        print("選擇編譯方式:")
        print("1. Google Colab")
        print("2. Local")

        choice = input("請輸入選擇（1 或 2）: ")

        if choice == '1':
            mount_drive()
            year = str(input("請輸入年份 year（i.e. 2021）："))
            main_file_name = str(input(f"請輸入 {year}_Cancer 所在的資料夾名稱（請記得先將 {year}_Cancer.csv 檔案放置在此資料夾）(i.e. 2023Report)"))
            choice_path = create_output_directory(main_file_name, year)
            file_path = os.path.join(choice_path, f'{year}_Cancer.csv')
            df = pd.read_csv(file_path)
            break  # Exit the loop if the choice is valid
        elif choice == '2':
            year = str(input("請輸入年份 year（i.e. 2021）："))
            main_file_name = str(input(f"請輸入 {year}_Cancer 所在的資料夾名稱（請記得先將 {year}_Cancer.csv 檔案放置在此資料夾）(i.e. 2023Report)"))
            choice_path = create_output_directory(main_file_name, year, is_colab=False)
            file_path = os.path.join(choice_path, f'{year}_Cancer.csv')
            df = pd.read_csv(file_path)
            break  # Exit the loop if the choice is valid
        else:
            print("請輸入正確的選擇（1 或 2）.")
    
    choice_path = os.path.join(choice_path, f'output{year}')
    
    # file_path = f'{main_file_name}/{year}_Cancer.csv'
    # df = pd.read_csv(file_path)
    df = clean_data(df)
    df = separate_class_of_carcinoma(df, main_file_name, year)
    Site_distribution = df['Site'].value_counts()
    print(Site_distribution)
# Out:
# 選擇編譯方式:
# 1. Google Colab
# 2. Local
# 請輸入選擇（1 或 2）:  2
# 請輸入年份 year（i.e. 2021）： 2021
# 請輸入 2021_Cancer 所在的資料夾名稱（請記得先將 2021_Cancer.csv 檔案放置在此資料夾）(i.e. 2023Report) 2023Report
# 目錄 '2023Report/output2021' 已成功建立！
# Site
# 其他（待確認）        241
# 乳癌             238
# 肺癌             164
# 結腸癌            157
# 攝護腺癌           109
# 肝癌              96
# 鼻咽癌             78
# 直腸癌             70
# 胃癌              69
# 膀胱癌             59
# 口腔癌             57
# 子宮頸癌            48
# 子宮體癌            40
# 白血病             38
# 胰臟癌             28
# 食道癌             24
# 卵巢癌             24
# 淋巴結(內)惡性淋巴癌     23
# 口咽癌             18
# 淋巴結(外)惡性淋巴瘤     14
# 喉癌               9
# 下咽癌              7
# 肛門癌              2
# Name: count, dtype: int64

# %% [markdown]
# ## carcinoma_type = "口腔癌"

# %%
from OralCavity_report import Type_Group, Type_Report, insite, oral_in_site_
carcinoma_type = "口腔癌"

file_path = f"{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}.csv"
df = pd.read_csv(file_path)
age_gender_report, class_gender_report, hist_distribution_report, df_AJCC_stage= generate_and_save_reports(df, carcinoma_type)

site_distribution_ = oral_in_site_(df, main_file_name, year, carcinoma_type)

order = ['1', '2', '3', '4A', '4B','BBB', '888', '999']
stage_distribution = Distribution_tabel(order, df_AJCC_stage, main_file_name, year, carcinoma_type)
OralCavity_therapy_ = therapy_order_Head_Neck_(df, main_file_name, year, carcinoma_type)
# Out:
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['年齡區間'] = df_report['診斷年齡'].apply(Age_Group)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['class'] = df_AJCC_stage['class'].str.replace("'", '').astype(int)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/OralCavity_report.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/OralCavity_report.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/OralCavity_report.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/OralCavity_report.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_site_distribution['class'] = df_site_distribution['class'].str.replace("'", '').astype(int)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/OralCavity_report.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_site_distribution["site"] = None
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/OralCavity_report.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_site_distribution["site"] = df_site_distribution["site-c"].apply(insite)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = therapy_df[i].str.replace(r"[^0-9]", '', regex=True)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = pd.to_numeric(therapy_df[i], errors='coerce')

# %% [markdown]
# ## carcinoma_type = "口咽癌"

# %%
from Oropharynx_report import Type_Group, Type_Report
carcinoma_type = "口咽癌"

file_path = f"{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}.csv"
df = pd.read_csv(file_path)
age_gender_report, class_gender_report, hist_distribution_report, df_AJCC_stage= generate_and_save_reports(df, carcinoma_type)

order = ['1', '2', '3', '4A', '4B','BBB', '888', '999']
stage_distribution = Distribution_tabel(order, df_AJCC_stage, main_file_name, year, carcinoma_type)
Oropharynx_therapy_ = therapy_order_Head_Neck_(df, main_file_name, year, carcinoma_type)
# Out:
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['年齡區間'] = df_report['診斷年齡'].apply(Age_Group)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['class'] = df_AJCC_stage['class'].str.replace("'", '').astype(int)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Oropharynx_report.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = therapy_df[i].str.replace(r"[^0-9]", '', regex=True)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = pd.to_numeric(therapy_df[i], errors='coerce')

# %% [markdown]
# ## carcinoma_type = "下咽癌"

# %%
from Hypopharynx_report import Type_Group, Type_Report
carcinoma_type = "下咽癌"

file_path = f"{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}.csv"
df = pd.read_csv(file_path)
age_gender_report, class_gender_report, hist_distribution_report, df_AJCC_stage= generate_and_save_reports(df, carcinoma_type)

order = ['1', '2', '3', '4A', '4B','BBB', '888', '999']
stage_distribution = Distribution_tabel(order, df_AJCC_stage, main_file_name, year, carcinoma_type)
Hypopharynx_therapy_ = therapy_order_Head_Neck_(df, main_file_name, year, carcinoma_type)
# Out:
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['年齡區間'] = df_report['診斷年齡'].apply(Age_Group)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['class'] = df_AJCC_stage['class'].str.replace("'", '').astype(int)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Hypopharynx_report.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Hypopharynx_report.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = therapy_df[i].str.replace(r"[^0-9]", '', regex=True)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = pd.to_numeric(therapy_df[i], errors='coerce')

# %% [markdown]
# ## carcinoma_type = "喉癌"

# %%
from Larynx_report import Type_Group, Type_Report
carcinoma_type = "喉癌"

file_path = f"{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}.csv"
df = pd.read_csv(file_path)
age_gender_report, class_gender_report, hist_distribution_report, df_AJCC_stage= generate_and_save_reports(df, carcinoma_type)

order = ['1', '2', '3', '4A', '4B','BBB', '888', '999']
stage_distribution = Distribution_tabel(order, df_AJCC_stage, main_file_name, year, carcinoma_type)
Larynx_therapy_ = therapy_order_Head_Neck_(df, main_file_name, year, carcinoma_type)
# Out:
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['年齡區間'] = df_report['診斷年齡'].apply(Age_Group)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['class'] = df_AJCC_stage['class'].str.replace("'", '').astype(int)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Larynx_report.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Larynx_report.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Larynx_report.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = therapy_df[i].str.replace(r"[^0-9]", '', regex=True)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = pd.to_numeric(therapy_df[i], errors='coerce')

# %% [markdown]
# ## carcinoma_type = "鼻咽癌"

# %%
from Nasopharynx_report import Type_Group, Type_Report
carcinoma_type = "鼻咽癌"

file_path = f"{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}.csv"
df = pd.read_csv(file_path)
age_gender_report, class_gender_report, hist_distribution_report, df_AJCC_stage= generate_and_save_reports(df, carcinoma_type)

order = ['1', '2', '3', '4A', '4B','BBB', '888', '999']
stage_distribution =  Distribution_tabel(order, df_AJCC_stage, main_file_name, year, carcinoma_type)
Nasopharynx_therapy_ = therapy_order_Head_Neck_(df, main_file_name, year, carcinoma_type)
# Out:
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_report['年齡區間'] = df_report['診斷年齡'].apply(Age_Group)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['class'] = df_AJCC_stage['class'].str.replace("'", '').astype(int)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/reports.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_AJCC_stage['STAGE'][i] = to_define_stage(df_AJCC_stage, i)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Nasopharynx_report.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Nasopharynx_report.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Nasopharynx_report.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Nasopharynx_report.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _distribution['percentage'][i] = (_distribution['count'][i]/carcinoma_in_situ).round(3)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = therapy_df[i].str.replace(r"[^0-9]", '', regex=True)
# /Users/liziyi/Downloads/WFHAutoAnnualReport-main 2/Head_and_Neck_Cancer_Treatment.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   therapy_df[i] = pd.to_numeric(therapy_df[i], errors='coerce')

# %%
from Larynx_report import Type_Group, Type_Report
carcinoma_type = "鼻咽癌"

file_path = f"{main_file_name}/output{year}/{year}{carcinoma_type}/{year}{carcinoma_type}.csv"
df = pd.read_csv(file_path)
age_gender_report, class_gender_report, hist_distribution_report, df_AJCC_stage= generate_and_save_reports(df, carcinoma_type)

order = ['1', '2', '3', '4A', '4B','BBB', '888', '999']
stage_distribution =  Distribution_tabel(order, df_AJCC_stage, main_file_name, year, carcinoma_type)
Nasopharynx_therapy_ = therapy_order_Head_Neck_(df, main_file_name, year, carcinoma_type)
